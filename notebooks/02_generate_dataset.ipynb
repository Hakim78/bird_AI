# %% [markdown]
# Import et lecture CSV

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: tqdm in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: matplotlib in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 4)) (3.10.1)
# Requirement already satisfied: librosa in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: soundfile in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 6)) (0.13.1)
# Requirement already satisfied: tensorflow in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: scikit-learn in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 8)) (1.6.1)
# Requirement already satisfied: notebook in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 9)) (7.4.1)
# Requirement already satisfied: ipython in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 10)) (9.2.0)
# Requirement already satisfied: streamlit in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from -r ../requirements.txt (line 11)) (1.45.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: colorama in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tqdm->-r ../requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (1.15.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from librosa->-r ../requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from soundfile->-r ../requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorflow->-r ../requirements.txt (line 7)) (0.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 7)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 7)) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r ../requirements.txt (line 7)) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r ../requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r ../requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from notebook->-r ../requirements.txt (line 9)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from notebook->-r ../requirements.txt (line 9)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0rc0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from notebook->-r ../requirements.txt (line 9)) (4.4.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from notebook->-r ../requirements.txt (line 9)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from notebook->-r ../requirements.txt (line 9)) (6.4.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (2.2.5)
# Requirement already satisfied: babel>=2.10 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (4.23.0)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython->-r ../requirements.txt (line 10)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r ../requirements.txt (line 10)) (0.2.13)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (8.1.8)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (20.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from streamlit->-r ../requirements.txt (line 11)) (0.9.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from altair<6,>=4.0->streamlit->-r ../requirements.txt (line 11)) (1.37.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 11)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 11)) (5.0.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from astunparse>=1.6.0->tensorflow->-r ../requirements.txt (line 7)) (0.45.1)
# Requirement already satisfied: pycparser in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from cffi>=1.0->soundfile->-r ../requirements.txt (line 6)) (2.22)
# Requirement already satisfied: httpcore==1.* in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (1.8.14)
# Requirement already satisfied: nest-asyncio in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook->-r ../requirements.txt (line 9)) (7.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jedi>=0.16->ipython->-r ../requirements.txt (line 10)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r ../requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (307)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (24.11.1)
# Requirement already satisfied: rich in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from keras>=3.5.0->tensorflow->-r ../requirements.txt (line 7)) (14.0.0)
# Requirement already satisfied: namex in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from keras>=3.5.0->tensorflow->-r ../requirements.txt (line 7)) (0.0.9)
# Requirement already satisfied: optree in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from keras>=3.5.0->tensorflow->-r ../requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (2.21.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from numba>=0.51.0->librosa->-r ../requirements.txt (line 5)) (0.44.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r ../requirements.txt (line 9)) (2.9.0.20241206)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from rich->keras>=3.5.0->tensorflow->-r ../requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r ../requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython->-r ../requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython->-r ../requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython->-r ../requirements.txt (line 10)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
# Chargement des métadonnées
csv_path = "../generate/new_metadata.csv"
metadata = pd.read_csv(csv_path)

# filtrage des sons 
metadata = metadata[metadata["type"].astype(str).str.contains("song|call", na=False)]
metadata = metadata[metadata["rating"] >= 4]
metadata.reset_index(drop=True, inplace=True)
# Vérifions les colonnes
metadata.head()
# Out:
#   primary_label             filename  type  rating  duration  samplerate
# 0        barswa  barswa/XC113914.ogg  song     5.0         5       32000
# 1        barswa  barswa/XC129647.ogg  song     5.0         5       32000
# 2        barswa  barswa/XC132406.ogg  song     5.0         5       32000
# 3        barswa  barswa/XC133096.ogg  song     5.0         5       32000
# 4        barswa  barswa/XC133802.ogg  song     5.0         5       32000

# %% [markdown]
# Partie 2 : définir le dossier de sortie

# %%
# dossier où les images seront stockées
output_base = "../Spectrograms"
os.makedirs(output_base, exist_ok=True)

# %% [markdown]
# Partie 3 : Fonction de génération de spectrogramme

# %%
def save_mel_spectrogram(audio_path, output_path):
    try:
        y, sr = librosa.load(audio_path, sr=22050, duration=10)  # limiter à 10 secondes
        S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        S_DB = librosa.power_to_db(S, ref=np.max)

        plt.figure(figsize=(3, 3))
        librosa.display.specshow(S_DB, sr=sr, cmap='magma')
        plt.axis('off')
        plt.tight_layout()
        plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
        plt.close()
        return True
    except Exception as e:
        print(f"❌ Erreur lors du traitement de {audio_path} : {e}")
        return False

# %% [markdown]
# Partie 4 : Boucle sur tous les fichiers audio python

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (8.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipywidgets) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: colorama in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: wcwidth in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\willi\documents\ecole_ipssi_mia4\avril_mai_2025\tp_groupe\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gc

success = 0
failed = 0

for idx, row in tqdm(metadata.iterrows(), total=len(metadata)):
    filename = row['filename']  # Exemple : "barswa/XC113914.ogg"
    label = row['primary_label']  # Exemple : "barswa"
    
    audio_path = os.path.join("..", "bird_audio", filename)
    output_dir = os.path.join(output_base, label)
    os.makedirs(output_dir, exist_ok=True)

    output_file = os.path.join(output_dir, os.path.basename(filename).replace(".ogg", ".png"))

    if os.path.exists(audio_path):
        try:
            ok = save_mel_spectrogram(audio_path, output_file)
            if ok:
                success += 1
            else:
                failed += 1
        except Exception as e:
            print(f"❌ Erreur pour {audio_path} : {e}")
            failed += 1
    else:
        print(f"❌ Fichier introuvable : {audio_path}")
        failed += 1

    gc.collect()  # Libération mémoire à chaque itération

print(f"✅ Terminé : {success} réussis, {failed} échoués.")
# Out:
# 100%|██████████| 2986/2986 [1:05:09<00:00,  1.31s/it]
# ✅ Terminé : 2986 réussis, 0 échoués.
